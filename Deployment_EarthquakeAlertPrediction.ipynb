# %%
import pickle
magnitude=float(input("Enter the Magnitude:"))
sig=int(input("Enter the significance:"))
depth=float(input("Enter the depth:"))
model=pickle.load(open('EarthQuake_Alert_Prediction.sav','rb'))
result=model.predict([[magnitude,sig,depth]])
print("ALERT:",result)
# Out:
# Enter the Magnitude:8.2
# Enter the significance:2089
# Enter the depth:19.36
# ALERT: ['red']
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"
