# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score

# %%
dataset=pd.read_csv("preprocessedEarthquake.csv")
df=dataset
order={'green':0,'yellow':1,'orange':2,'red':3}
df['Encoded_Level']=df['alert'].map(order)
df.columns
# Out:
# Index(['magnitude', 'cdi', 'mmi', 'alert', 'sig', 'dmin', 'gap', 'depth',
#        'Encoded_Level'],
#       dtype='object')

# %%
df['Encoded_Level'].value_counts()
# Out:
# 0    325
# 1     56
# 2     22
# 3     12
# Name: Encoded_Level, dtype: int64

# %%
indep=df[['magnitude','sig', 'depth']]
dep=df[['Encoded_Level']]
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=0.25,random_state=0)
y_test['Encoded_Level'].value_counts()
# Out:
# 0    81
# 1    14
# 3     5
# 2     4
# Name: Encoded_Level, dtype: int64

# %%
sc=StandardScaler()
Sc_x_train=sc.fit(x_train)
Sc_x_test=sc.transform(x_test)

# %%
def Grid(classifier,parameters,x_train,y_train,x_test,y_test):
    grid=GridSearchCV(classifier,parameters,refit=True,n_jobs=1,scoring='accuracy')
    grid.fit(x_train,y_train)
    y_pred=grid.predict(x_test)
    #roc_auc=roc_auc_score(y_test,grid.predict_proba(x_test)[:,1],multi_class='ovo')
    cm=confusion_matrix(y_test,y_pred)
    report=classification_report(y_test,y_pred)
    F1=f1_score(y_test,y_pred,average='weighted')
    result=grid.cv_results_
    table=pd.DataFrame.from_dict(result)
    print("The Best Parameters are: {} ".format(grid.best_params_),F1)
    return cm,report,F1,table

# %%
logistic=LogisticRegression()
parameters={'penalty':['l2','None'],'C':[0.01,0.1,1.0,10.0],'random_state':[0,42,45,50],'solver':['lbfgs','newton_cg','newton_cholesky','sag','saga']}
cm,report,F1,table=Grid(logistic,parameters,x_train,y_train,x_test,y_test)
# Out:
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# ...

# %%
cm
# Out:
# array([[78,  1,  2,  0],
#        [11,  3,  0,  0],
#        [ 1,  2,  1,  0],
#        [ 0,  0,  2,  3]], dtype=int64)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91        81
#            1       0.50      0.21      0.30        14
#            2       0.20      0.25      0.22         4
#            3       1.00      0.60      0.75         5
#
#     accuracy                           0.82       104
#    macro avg       0.64      0.51      0.55       104
# weighted avg       0.80      0.82      0.80       104

# %%
F1
# Out:
# 0.79551563202879

# %%
table[table['rank_test_score']==1]
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 120       0.023380      0.005716         0.000600        0.000800      10
# 125       0.021601      0.009812         0.006589        0.007671      10
# 130       0.025513      0.008233         0.000000        0.000000      10
# 135       0.027137      0.009457         0.000000        0.000000      10
#
#     param_penalty param_random_state param_solver  \
# 120            l2                  0        lbfgs
# 125            l2                 42        lbfgs
# 130            l2                 45        lbfgs
# 135            l2                 50        lbfgs
#
#                                                 params  split0_test_score  \
# 120  {'C': 10.0, 'penalty': 'l2', 'random_state': 0...            0.84127
# 125  {'C': 10.0, 'penalty': 'l2', 'random_state': 4...            0.84127
# 130  {'C': 10.0, 'penalty': 'l2', 'random_state': 4...            0.84127
# ...

# %%
svc=SVC()
parameters={'C':[0.01,0.1,1.0,10.0,100.0],'kernel':['linear','poly','rbf','sigmoid']}
cm,report,F1,table=Grid(svc,parameters,x_train,y_train,x_test,y_test)
# Out:
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
cm
# Out:
# array([[77,  2,  2,  0],
#        [11,  3,  0,  0],
#        [ 1,  2,  1,  0],
#        [ 0,  1,  1,  3]], dtype=int64)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91        81
#            1       0.38      0.21      0.27        14
#            2       0.25      0.25      0.25         4
#            3       1.00      0.60      0.75         5
#
#     accuracy                           0.81       104
#    macro avg       0.62      0.50      0.54       104
# weighted avg       0.78      0.81      0.79       104

# %%
F1
# Out:
# 0.7879293500617031

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.087298      0.036268         0.001198        0.000979    0.01
# 1        0.004324      0.005910         0.000926        0.001152    0.01
# 2        0.003201      0.000400         0.001800        0.000399    0.01
# 3        0.003567      0.006009         0.000000        0.000000    0.01
# 4        0.323103      0.044230         0.000401        0.000801     0.1
# 5        0.003223      0.006445         0.003177        0.004007     0.1
# 6        0.000000      0.000000         0.006426        0.007871     0.1
# 7        0.000000      0.000000         0.003173        0.006345     0.1
# 8        1.457327      0.463221         0.003202        0.006403       1
# 9        0.003223      0.006446         0.000000        0.000000       1
# 10       0.000833      0.001667         0.007008        0.007367       1
# 11       0.001690      0.003380         0.003228        0.006456       1
# ...

# %%
DTC=DecisionTreeClassifier()
parameters={'criterion':['gini','entropy','log_loss'],'splitter':['best','random'],'random_state':[0,42],'max_features':['sqrt','log2']}
cm,report,F1,table=Grid(DTC,parameters,x_train,y_train,x_test,y_test)
# Out:
# The Best Parameters are: {'criterion': 'gini', 'max_features': 'sqrt', 'random_state': 0, 'splitter': 'best'}  0.8348381801125703
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda\envs\aiml\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda\envs\aiml\lib\site-packages\sklearn\tree\_classes.py", line 942, in fit
#     X_idx_sorted=X_idx_sorted,
# ...

# %%
cm
# Out:
# array([[76,  3,  2,  0],
#        [ 7,  6,  1,  0],
#        [ 0,  2,  2,  0],
#        [ 0,  2,  0,  3]], dtype=int64)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        81
#            1       0.46      0.43      0.44        14
#            2       0.40      0.50      0.44         4
#            3       1.00      0.60      0.75         5
#
#     accuracy                           0.84       104
#    macro avg       0.69      0.62      0.64       104
# weighted avg       0.84      0.84      0.83       104

# %%
F1
# Out:
# 0.8348381801125703

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003146      0.003214         0.000601        0.000810
# 1        0.003074      0.000747         0.001206        0.000747
# 2        0.003020      0.006039         0.003154        0.006307
# 3        0.000000      0.000000         0.003140        0.006279
# 4        0.003407      0.001766         0.004189        0.005872
# 5        0.002246      0.001839         0.000408        0.000500
# 6        0.006165      0.007554         0.000000        0.000000
# 7        0.006272      0.007681         0.000000        0.000000
# 8        0.003191      0.006382         0.000000        0.000000
# 9        0.006347      0.007791         0.000000        0.000000
# 10       0.006277      0.007688         0.000000        0.000000
# 11       0.000000      0.000000         0.003135        0.006270
# 12       0.000000      0.000000         0.006268        0.007676
# ...

# %%
RFC=RandomForestClassifier()
parameters={'n_estimators':[10,50,100,150,200],'criterion':['gini','entropy','log_loss'],'max_features':['sqrt','log2'],'random_state':[0,42,45,50]}
cm,report,F1,table=Grid(RFC,parameters,x_train,y_train,x_test,y_test)
# Out:
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\model_selection\_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\model_selection\_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\model_selection\_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
cm
# Out:
# array([[79,  2,  0,  0],
#        [ 9,  3,  2,  0],
#        [ 1,  1,  2,  0],
#        [ 0,  2,  0,  3]], dtype=int64)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93        81
#            1       0.38      0.21      0.27        14
#            2       0.50      0.50      0.50         4
#            3       1.00      0.60      0.75         5
#
#     accuracy                           0.84       104
#    macro avg       0.69      0.57      0.61       104
# weighted avg       0.81      0.84      0.82       104

# %%
F1
# Out:
# 0.8158705265322912

# %%
table
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.009619      0.008401         0.008985        0.006166
# 1         0.015115      0.001292         0.001468        0.001468
# 2         0.015834      0.002271         0.001508        0.001272
# 3         0.020447      0.010821         0.001852        0.000703
# 4         0.053407      0.004367         0.002394        0.001954
# ..             ...           ...              ...             ...
# 115       0.039909      0.006606         0.000000        0.000000
# 116       0.058583      0.007538         0.000000        0.000000
# 117       0.058844      0.006952         0.000000        0.000000
# 118       0.053009      0.006885         0.000000        0.000000
# 119       0.056058      0.008531         0.000000        0.000000
#
#     param_criterion param_max_features param_n_estimators param_random_state  \
# 0              gini               sqrt                 10                  0
# ...

# %%
KNN=KNeighborsClassifier()
parameters={'n_neighbors':[1,2,3,4,5,6,7],'weights':['uniform','distance'],'algorithm':['auto','ball_tree','kd_tree','brute']}
cm,report,F1,table=Grid(KNN,parameters,x_train,y_train,x_test,y_test)
# Out:
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
cm
# Out:
# array([[78,  1,  2,  0],
#        [ 8,  3,  3,  0],
#        [ 0,  3,  1,  0],
#        [ 0,  3,  0,  2]], dtype=int64)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93        81
#            1       0.30      0.21      0.25        14
#            2       0.17      0.25      0.20         4
#            3       1.00      0.40      0.57         5
#
#     accuracy                           0.81       104
#    macro avg       0.59      0.46      0.49       104
# weighted avg       0.80      0.81      0.80       104

# %%
F1
# Out:
# 0.7963635914983219

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.008230      0.010525         0.004877        0.001841
# 1        0.004026      0.002162         0.001589        0.000795
# 2        0.004765      0.005812         0.000800        0.001166
# 3        0.005163      0.005936         0.001583        0.000833
# 4        0.001801      0.001600         0.004398        0.005951
# 5        0.003183      0.006365         0.000000        0.000000
# 6        0.004095      0.006229         0.002137        0.004273
# 7        0.003570      0.000471         0.002017        0.000035
# 8        0.000794      0.001588         0.003152        0.006303
# 9        0.004639      0.006233         0.003169        0.006337
# 10       0.000000      0.000000         0.004816        0.006324
# 11       0.006364      0.007795         0.000000        0.000000
# 12       0.003133      0.006266         0.005679        0.007032
# ...

# %%
GNB=GaussianNB()
parameters={'var_smoothing':[1e-11,1e-10,1e-9,1e-8,1e-7]}
cm,report,F1,table=Grid(GNB,parameters,x_train,y_train,x_test,y_test)
# Out:
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\envs\aiml\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
cm
# Out:
# array([[73,  5,  3,  0],
#        [ 9,  4,  1,  0],
#        [ 2,  1,  1,  0],
#        [ 0,  0,  1,  4]], dtype=int64)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88        81
#            1       0.40      0.29      0.33        14
#            2       0.17      0.25      0.20         4
#            3       1.00      0.80      0.89         5
#
#     accuracy                           0.79       104
#    macro avg       0.61      0.56      0.58       104
# weighted avg       0.79      0.79      0.78       104

# %%
F1
# Out:
# 0.7844599844599844

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.004497      0.004242         0.001291        0.001165
# 1       0.005550      0.005732         0.000709        0.000881
# 2       0.001408      0.001211         0.003334        0.004750
# 3       0.002769      0.000391         0.001613        0.000474
# 4       0.003046      0.000614         0.001826        0.000345
#
#   param_var_smoothing                    params  split0_test_score  \
# 0               1e-11  {'var_smoothing': 1e-11}           0.809524
# 1               1e-10  {'var_smoothing': 1e-10}           0.809524
# 2               1e-09  {'var_smoothing': 1e-09}           0.809524
# 3               1e-08  {'var_smoothing': 1e-08}           0.809524
# 4               1e-07  {'var_smoothing': 1e-07}           0.793651
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.806452           0.790323           0.790323           0.693548
# ...
